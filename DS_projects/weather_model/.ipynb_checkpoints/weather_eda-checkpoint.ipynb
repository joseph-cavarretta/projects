# %%
import os
import pandas as pd
from datetime import datetime, date
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\josep\\python_projects\\DS_projects\\weather_model'

# %%
# historical weather data for Boulder, CO
raw_df = pd.read_csv('weather_data_historical.csv')

# change dt_iso to datetime
# original format: YYYY-MM-DD 00:00:00 +0000 UTC
raw_df['dt_iso'] = raw_df['dt_iso'].str[:-10]

raw_df['dt_iso'] = pd.to_datetime(raw_df['dt_iso'], format='%Y-%m-%d %H:%M:%S')

'''
temp_min / temp_max - the min and max temps at the moment
timezone - shift in seconds from UTC
temp - C
visibility - m
dew_point - kelvin
feels like - C
pressure - hPA
humidity - %
wind_speed - m/s
wind_deg - deg (meteorological)
wind_gust - m/s
rain_1h - mm
snow_1h - mm
clouds_all - %
weather_id - weather condition id
weather_main - group of weather parameters (rain, snow, extreme)
''';

# %%
# drop columns with all null values
raw_df.drop(columns=['sea_level', 'grnd_level', 'snow_3h', 'rain_3h' ], inplace=True)

# drop unneeded columns
raw_df.drop(
    columns=[
        'dt', 
        'timezone', 
        'city_name', 
        'lat', 
        'lon', 
        'clouds_all', 
        'weather_id', 
        'weather_main', 
        'weather_description',
        'weather_icon'
    ], inplace=True
)

# %%
# create additional date columns
raw_df['month_name'] = raw_df['dt_iso'].dt.month_name()
raw_df['year'] = raw_df['dt_iso'].dt.year
raw_df['month'] = raw_df['dt_iso'].dt.month
raw_df['day_of_month'] = raw_df['dt_iso'].dt.day
raw_df['day_of_year'] = raw_df['dt_iso'].dt.strftime('%j')

# %%
raw_df.columns
# Out:
# Index(['dt_iso', 'temp', 'visibility', 'dew_point', 'feels_like', 'temp_min',
#        'temp_max', 'pressure', 'humidity', 'wind_speed', 'wind_deg',
#        'wind_gust', 'rain_1h', 'snow_1h', 'month_name', 'year', 'month',
#        'day_of_month', 'day_of_year'],
#       dtype='object')

# %%
# reorder columns
cols = [
    'dt_iso',
    'year',
    'month',
    'month_name',
    'day_of_month',
    'day_of_year',
    'temp',
    'feels_like',
    'wind_speed',
    'wind_gust',
    'rain_1h',
    'snow_1h',
    'pressure',
    'humidity'
]

# %%
# make copy of raw_df with filtered columns 
df = raw_df[cols].copy()

# %%
# sort just to make sure
df.sort_values('dt_iso', inplace=True)

# %%
##### HANDLE NAN VALUES

# if wind_gust = NaN, fill with value from wind_speed
df['wind_gust'] = df['wind_gust'].fillna(df['wind_speed'])

# fill NaN for snow and rainfall with 0
df[['rain_1h', 'snow_1h']] = df[['rain_1h', 'snow_1h']].fillna(float(0))

# %%
# which features are correlated?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378309 entries, 0 to 378308
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   dt_iso        378309 non-null  datetime64[ns]
#  1   year          378309 non-null  int64
#  2   month         378309 non-null  int64
#  3   month_name    378309 non-null  object
#  4   day_of_month  378309 non-null  int64
#  5   day_of_year   378309 non-null  object
#  6   temp          378309 non-null  float64
#  7   feels_like    378309 non-null  float64
#  8   wind_speed    378309 non-null  float64
#  9   wind_gust     378309 non-null  float64
#  10  rain_1h       378309 non-null  float64
#  11  snow_1h       378309 non-null  float64
#  12  pressure      378309 non-null  int64
#  13  humidity      378309 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(2)
# memory usage: 43.3+ MB

# %%
df.describe()
# Out:
#                 year          month   day_of_month           temp  \
# count  378309.000000  378309.000000  378309.000000  378309.000000
# mean     2000.060435       6.521373      15.729163       7.167040
# std        12.429061       3.445542       8.799719      10.750865
# min      1979.000000       1.000000       1.000000     -33.680000
# 25%      1989.000000       4.000000       8.000000      -0.860000
# 50%      2000.000000       7.000000      16.000000       6.940000
# 75%      2011.000000      10.000000      23.000000      15.000000
# max      2021.000000      12.000000      31.000000      39.110000
#
#           feels_like     wind_speed      wind_gust        rain_1h  \
# count  378309.000000  378309.000000  378309.000000  378309.000000
# mean        5.368054       2.170199       2.347337       0.071514
# std        11.803601       1.509001       1.952375       0.364716
# min       -40.130000       0.000000       0.000000       0.000000
# 25%        -3.330000       1.210000       1.320000       0.000000
# 50%         5.750000       2.030000       2.060000       0.000000
# 75%        14.070000       2.990000       3.080000       0.000000
# max        36.000000      24.700000      32.900000      31.500000
#
#              snow_1h       pressure       humidity
# count  378309.000000  378309.000000  378309.000000
# mean        0.027476    1015.340227      60.594038
# std         0.212643       7.329379      21.618479
# min         0.000000     969.000000       2.000000
# 25%         0.000000    1011.000000      44.000000
# 50%         0.000000    1016.000000      63.000000
# 75%         0.000000    1020.000000      78.000000
# max        42.420000    1087.000000     100.000000

# %%
df.head()
# Out:
#                dt_iso  year  month month_name  day_of_month day_of_year  \
# 0 1979-01-01 00:00:00  1979      1    January             1         001
# 1 1979-01-01 01:00:00  1979      1    January             1         001
# 2 1979-01-01 02:00:00  1979      1    January             1         001
# 3 1979-01-01 03:00:00  1979      1    January             1         001
# 4 1979-01-01 04:00:00  1979      1    January             1         001
#
#     temp  feels_like  wind_speed  wind_gust  rain_1h  snow_1h  pressure  \
# 0 -18.89      -24.48        2.01       2.01      0.0      0.0      1027
# 1 -18.96      -23.40        1.51       1.51      0.0      0.0      1029
# 2 -19.91      -19.91        1.11       1.11      0.0      0.0      1029
# 3 -21.07      -21.07        0.89       0.89      0.0      0.0      1030
# 4 -20.43      -20.43        0.85       0.85      0.0      0.0      1031
#
#    humidity
# 0        77
# 1        76
# 2        80
# 3        81
# 4        78

# %%
df[df.year >= 2000].plot(kind = 'line',
        x = 'dt_iso',
        y = 'temp',
        color = 'red')
# Out:
# <AxesSubplot:xlabel='dt_iso'>
